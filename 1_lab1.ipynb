# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

    
import os
#from openai import OpenAI
from dotenv import load_dotenv
load_dotenv(override=True)

#DEEPSEEK_BASE_URL = "https://api.deepseek.com/v1"
deepseek_api_key = os.getenv("DEEPSEEK_API_KEY")

if deepseek_api_key:
    print(f"deepseek API Key exists and begins {deepseek_api_key[:8]}")
else:
    print("deepseek API Key not set - please head to the troubleshooting guide in the setup folder")
#deepseek = OpenAI(base_url=DEEPSEEK_BASE_URL, api_key=deepseek_api_key)
#response = deepseek.chat.completions.create(model="deepseek-chat", messages=[{"role":"user", "content": "what is 2+2?"}])
#print(response.choices[0].message.content)
# Out:
# deepseek API Key exists and begins sk-a46c9

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)
DEEPSEEK_BASE_URL = "https://api.deepseek.com/v1"
deepseek = OpenAI(base_url=DEEPSEEK_BASE_URL, api_key=deepseek_api_key)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = deepseek.chat.completions.create(
    model="deepseek-chat",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# That’s a classic!
#
# \[
# 2 + 2 = 4
# \]

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = deepseek.chat.completions.create(
    model="deepseek-chat",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# A perfect logician is told: "I have hidden a real number on the interval (0, 100]. You may ask me only yes/no questions of the form 'Is the number greater than x?' where x is any real number you choose. I will answer truthfully, but after my third answer, I will give no further information. What is the optimal strategy to determine the number with the highest possible guaranteed precision, and what is that precision?"

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = deepseek.chat.completions.create(
    model="deepseek-chat",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# A perfect logician is given a set of 12 coins, one of which is counterfeit and differs in weight (heavier or lighter) from the rest. Using only a balance scale three times, how can the logician identify the counterfeit coin *and* determine whether it is heavier or lighter?

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# A perfect logician is given a set of 12 coins, one of which is counterfeit and differs in weight (heavier or lighter) from the rest. Using only a balance scale three times, how can the logician identify the counterfeit coin *and* determine whether it is heavier or lighter?

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "South Indian Jewellery"}]

# Then make the first call:

response = deepseek.chat.completions.create(
    model="deepseek-chat",
    messages=messages
)

# Then read the business idea:
business_idea = response.choices[0].message.content
#print(business_idea)

from IPython.display import Markdown, display

display(Markdown(business_idea))

#messages = [{"role": "user", "content": "Present a pain point in that industry"}]
response = deepseek.chat.completions.create(
    model="deepseek-chat",
    messages=[{"role": "user", "content": "Present a pain point in south indian jewellery industry"}]
)

business_pain_point = response.choices[0].message.content
display(Markdown(business_pain_point))

response = deepseek.chat.completions.create(
    model = "deepseek-chat",
    messages = [{"role" : "user", "content":"Propose a solution for the pain points of south indian jewellery"}]

)

business_solution = response.choices[0].message.content
display(Markdown(business_solution))
# Out:
# Of course! South Indian jewellery is a magnificent and distinct tradition, renowned for its **grandeur, intricate craftsmanship, symbolic significance, and deep cultural roots.** It's more than just adornment; it's a statement of heritage, status, and often a family heirloom passed down through generations.
#
# Here’s a comprehensive guide to its key characteristics, iconic pieces, and cultural context.
#
# ### **Core Characteristics**
# *   **Heavy & Substantial:** Unlike delicate jewellery, South Indian pieces are famously weighty, made with high-purity gold (often 22K).
# *   **Temple Inspiration:** Much of the design is inspired by temple architecture, deities, and motifs (like the *gopuram* or temple tower).
# *   **Intricate Craftsmanship:** Techniques like **temple jewellery** (*Temple Jewellery* or *Temple Muthu*), **kundan**, **meenakari** (enameling), **filigree**, and **granulation** are used to create stunning details.
# *   **Symbolic & Religious Motifs:** Common motifs include gods & goddesses (Lakshmi, Ganesha), peacocks, elephants, lotus flowers, mangoes (*mukkan*), and celestial symbols.
# *   **Rudraksha & Gemstones:** Natural elements like **rudraksha beads** and vibrant gemstones (rubies, emeralds, uncut diamonds) are frequently incorporated.
#
# ---
#
# ### **Iconic Pieces of South Indian Jewellery**
#
# #### **For the Head & Hair**
# *   **Jadanagam:** A braid ornament, often a gold chain with pendants, worn woven into a long braid.
# *   **Rakkodi:** A circular ornament worn at the back of the head.
# *   **Surya Pirai & Chandra Pirai:** Sun and moon-shaped ornaments worn on either side of the parting.
# *   **Maang Tikka (Nethi Chutti):** Worn on the forehead, extending to the hairline.
#
# #### **For the Ears**
# *   **Jhumkas:** Large, bell-shaped earrings, often temple-style.
# *   **Lola Kammal:** Dome-shaped studs, sometimes with hanging pearls.
# *   **Mattu (Ear Cuffs):** Ornaments that cover the entire ear cartilage.
#
# #### **For the Neck**
# *   **Vaddanam / Odiyanam:** The most iconic piece—a **wide, heavy waist belt** worn over sarees. It's a symbol of marriage and grandeur.
# *   **Manga Malai:** A necklace with stylized mango-shaped pendants.
# *   **Kasulaperu / Lakshmi Haar:** A long gold chain with iconic gold coins (often depicting Lakshmi).
# *   **Ravanahatha:** A choker with a central pendant, often with a deity motif.
# *   **Choker (Gulabi):** A broad, rigid necklace covering the neck.
#
# #### **For the Arms & Wrists**
# *   **Vanki / Armlet:** An elaborate ornament worn on the upper arm.
# *   **Bangles (Gajulu):** Stacks of solid gold bangles or intricately designed ones.
# *   **Gold Chain Bracelets:** Often with a central pendant.
#
# #### **For the Feet**
# *   **Metti / Toe Rings:** Simple or twisted gold rings, a symbol of marriage.
# *   **Padasaram / Anklets:** Delicate chains with small bells.
#
# ---
#
# ### **Regional Variations & Styles**
#
# 1.  **Temple Jewellery:** The most famous style. Originally crafted for temple deities and dancers (*Bharatanatyam, Kuchipudi*), it features repoussé work, red and green gemstones (rubies & emeralds), and motifs of gods, peacocks, and lotus. Now a bridal essential.
# 2.  **Nagercoil Jewellery:** From Tamil Nadu, known for its **filigree work**—creating delicate, lace-like patterns with fine gold or silver wires.
# 3.  **Kerala Style:** Distinctly different, often using **green gold** (an alloy with higher silver content). Features nature motifs, minimal stones, and iconic pieces like the **Mulla Mottu Mala** (jasmine bud necklace) and **Palakka Mala** (leaf-shaped pendant).
# 4.  **Kundan & Polki:** Though North Indian in origin, these styles (uncut diamonds set in gold foil) are beautifully integrated into South Indian bridal sets for added opulence.
#
# ---
#
# ### **Cultural Significance**
# *   **Bridal Adornment (Muhurtham):** A South Indian bride is literally covered in gold from head to toe. Each piece she wears is a blessing, a symbol of prosperity, and a shield against evil.
# *   **Dance Ornamentation:** Temple jewellery is integral to classical dance forms, helping tell stories through visual symbolism.
# *   **Heirlooms (Pattam):** Jewellery is considered a store of wealth and is passed from mother to daughter, carrying family history and blessings.
# *   **Religious & Ritualistic:** Specific ornaments are worn for religious ceremonies and festivals.
#
# ---
#
# ### **Modern Interpretations**
# Contemporary designers are brilliantly reinterpreting these traditional styles:
# *   **Lightweight Versions:** Creating pieces with the same aesthetic for daily wear.
# *   **Fusion Designs:** Blending temple motifs with modern minimalistic chains or using silver as a base.
# *   **Versatile Pieces:** Transforming a **vaddanam** into a necklace or using a **rakkodi** as a brooch.
#
# **In essence, South Indian jewellery is a living art form—a breathtaking blend of sacred symbolism, unparalleled craftsmanship, and timeless beauty that continues to evolve while staying rooted in its glorious past.**
# Of course. A significant and multifaceted pain point in the South Indian jewellery industry is the **generational shift in consumer preferences and the resulting identity crisis for traditional jewellers.**
#
# This isn't just about a decline in sales; it's a clash between deep-rooted heritage and rapidly evolving modern lifestyles.
#
# ### **The Core Pain Point: The "Heirloom vs. Everyday" Dilemma**
#
# Traditional South Indian jewellery (Temple jewellery, Kundan, Polki, elaborate gold sets with specific motifs like *jamakkalam*, *rudraksha*, and *manga malai*) is engineered for **occasion-wear, symbolism, and storing wealth.** The modern consumer, especially urban women under 40, prioritizes **lightweight, versatile, daily-wear designs that express personal style over pure tradition.**
#
# ---
#
# ### **Breaking Down the Pain Point:**
#
# **1. Changing Lifestyles & Practicality:**
# *   **Weight & Comfort:** Heavy traditional sets are impractical for daily life in urban, professional settings.
# *   **Occasion-Centric:** Grand pieces are worn only a few times a year (weddings, festivals), leading to low purchase frequency.
# *   **Security Concerns:** Wearing high-value, recognizable traditional pieces daily poses safety risks.
#
# **2. Evolving Aesthetic & Value Perception:**
# *   **From Investment to Accessory:** Younger buyers still value gold as an asset but give equal (or greater) weight to design, craftsmanship (karigari), and wearability. The piece must earn its place in a daily wardrobe.
# *   **Fusion Over Pure Traditional:** Demand is high for "fusion" jewellery—traditional motifs in lighter, smaller forms, or mixed with diamonds, gemstones, or even wearable in contemporary ways (e.g., a *vanki* adapted as a cocktail ring).
# *   **Global Influences:** Exposure to global minimalist trends competes with the traditional "more is more" aesthetic.
#
# **3. The Inventory & Business Model Challenge for Jewellers:**
# *   **High-Capital, Slow-Moving Stock:** Traditional heavy pieces lock up enormous capital in inventory that moves slowly.
# *   **Skill Gap:** Artisans skilled in traditional *mattal* (filigree) and temple work are aging, with fewer successors. Adapting these skills to lighter, modern designs is a challenge.
# *   **Marketing Disconnect:** Legacy marketing (focusing on purity, weight, and auspiciousness) doesn't resonate with the younger audience seeking storytelling around design, versatility, and craftsmanship.
#
# **4. Competition from New Players:**
# *   **Lifestyle & Branded Jewellery:** Brands like Tanishq (with its Mia collection), Melorra, and BlueStone offer lightweight, trendy, and modular jewellery marketed directly for the "everyday" woman.
# *   **Online Disruption:** The traditional model relies on in-store, trust-based purchases. Younger consumers are comfortable researching, comparing, and buying lighter jewellery online.
#
# ---
#
# ### **The Consequence: An Industry at a Crossroads**
#
# Traditional family-owned jewellers (**"A & Sons"**) face a critical choice:
# *   **Stick purely to tradition:** Risk becoming irrelevant to the future core customer, serving only a shrinking segment for occasional purchases.
# *   **Adapt and evolve:** Risk alienating their older, loyal clientele who value purity and tradition, while navigating a new design and marketing landscape.
#
# **The real pain is the balancing act:** How to **honor and preserve the rich heritage and unparalleled craftsmanship** of South Indian jewellery while **reinterpreting it for a generation that lives, dresses, and thinks differently.**
#
# ### **Emerging Solutions (Glimmers of Hope):**
# *   **Design Innovation:** Many legacy houses are now launching "lightweight" or "fusion" sub-brands.
# *   **Modular Jewellery:** Creating traditional sets that can be broken down and worn as separate daily pieces (e.g., a *haram* (long necklace) with detachable pendants).
# *   **Storytelling & Craftsmanship Marketing:** Shifting focus from just "gold weight" to the artisanal story, the motif's meaning, and the technical skill involved.
# *   **Experience over Transaction:** Transforming stores into experiential spaces that educate about heritage while showcasing wearable modern collections.
#
# **In essence, the pain point is the tension between preserving a magnificent cultural legacy and adapting to a commercial reality defined by changing tastes and lifestyles. The survival of the traditional art form depends on the industry's ability to innovate without dilution.**
# Of course. South Indian jewellery, renowned for its intricate craftsmanship, cultural depth, and use of high-purity gold, faces several modern-day pain points. Here is a comprehensive solution framework addressing these issues from the perspectives of the consumer, the artisan, and the retailer.
#
# ### **Core Pain Points & Proposed Solutions**
#
# #### **1. Pain Point: High Cost & Capital Intensity**
# *   **Problem:** The use of 22K-24K gold and heavy weight makes pieces extremely expensive, limiting accessibility for everyday wear and younger buyers.
# *   **Solution: Modular & Lightweight Designs**
#     *   **Concept:** Create jewellery in lighter weights using techniques like *jadai* (filigree), hollow construction, and sheet gold to reduce gold content without compromising visual impact.
#     *   **Modularity:** Design pieces where a central, heavier traditional element (e.g., a **Temple Mango Mala** centerpiece) can be detached and worn with lighter, interchangeable gold-plated silver or alloy chains for daily use. This offers "one heavy piece, multiple looks."
#     *   **Subscription/Leasing Models:** For weddings, offer a "heritage leasing" service where the core heavy set is leased, while complementary lighter pieces are sold.
#
# #### **2. Pain Point: Lack of Daily Wear Usability**
# *   **Problem:** Traditional pieces like **Vaddanams** (waist belts), **Rakkadis** (headpieces), and long **Mala** (chains) are perceived as too ornate and cumbersome for daily life.
# *   **Solution: Contemporary Reinterpretation & Styling Education**
#     *   **Re-design:** Adapt motifs (peacocks, temple, lotus) into contemporary forms—dainty **Jhumkis**, stackable **Vanki**-inspired bangles, minimalist **Nath** studs.
#     *   **Styling Workshops:** Partner with fashion influencers and stylists to show how a traditional **Kasu Mala** (coin chain) can be layered with modern pendants or how **Oddiyanams** (anklets) can be styled with ethnic-chic casual wear. Content is key.
#
# #### **3. Pain Point: Safety & Practicality Concerns**
# *   **Problem:** Heavy jewellery can be unsafe in crowded areas, attracts unwanted attention, and is difficult to manage physically.
# *   **Solution: Secure Engineering & Wearable Tech Integration**
#     *   **Security Features:** Integrate discrete, modern clasps, locking mechanisms, and breakaway features for safety. Use durable, hypoallergergic backing for long wear.
#     *   **"Smart Jewellery" Fusion:** Embed tiny tracking chips (activated only by the owner) in pieces for security. Design lighter, activity-friendly versions of traditional pieces for modern lifestyles.
#
# #### **4. Pain Point: Preservation of Dying Artisanship**
# *   **Problem:** **Kundan**, **Meenakari**, and intricate hand-embossing skills are fading due to low wages, long apprenticeship periods, and lack of recognition.
# *   **Solution: Artisan-Centric Business Models & Direct Platforms**
#     *   **Co-operative Models & Fair Trade:** Establish brand collectives that ensure artisans receive fair wages, healthcare, and credit. Market pieces with the artisan's story and signature.
#     *   **Digital Platforms:** Create an "Etsy-like" curated platform specifically for master South Indian jewellers (**Thattans**) to sell directly or through limited editions.
#     *   **Government & NGO Collaboration:** Certify master artisans, offer subsidized advanced tools (laser welders, precision carvers) to reduce physical strain and increase efficiency without losing the handcrafted soul.
#
# #### **5. Pain Point: Inconsistent Quality & Hallmarking Trust**
# *   **Problem:** Despite BIS hallmarking, concerns about purity and quality persist, especially with intricate pieces where alloy mixing can occur.
# *   **Solution: Hyper-Transparency & Technology**
#     *   **Blockchain for Provenance:** Use blockchain to record every step—gold source, purity at each stage, artisan touchpoints, hallmarking certificate—accessible via a QR code.
#     *   **In-Store Tech:** Install non-destructive XRF (X-ray fluorescence) testers in flagship stores, allowing customers to see the purity reading of their piece instantly.
#
# #### **6. Pain Point: Limited Marketing & Perception of Being "Old-Fashioned"**
# *   **Problem:** Marketing often targets only bridal or older demographics, missing out on the global, fashion-conscious audience.
# *   **Solution: Aggressive Re-branding & Digital Storytelling**
#     *   **Content-Driven Marketing:** Produce high-quality documentaries on the art, craft, and science behind the jewellery. Use Instagram Reels, YouTube to show the making process.
#     *   **Global Collaborations:** Partner with global fashion designers to include South Indian motifs in international collections. Position pieces as "wearable art" and "cultural heritage," not just ornamentation.
#     *   **Virtual Try-On (VTO):** Develop robust AR apps for customers to try on heavy necklaces or **Jimkis** virtually, reducing the intimidation factor of walking into a large store.
#
# ---
#
# ### **Integrated Solution: "The Temple Heritage Project" – A Proposed Model**
#
# A hypothetical brand or initiative that encapsulates all solutions:
#
# *   **Product Lines:**
#     1.  **Heritage Heirlooms:** Full-weight, artisan-signed pieces with blockchain provenance. (Investment/Bridal)
#     2.  **Temple Lite:** Lightweight, daily-wear collections with traditional motifs. (Accessible Fashion)
#     3.  **Modular Collective:** Interchangeable cores and chains. (Versatile Middle Segment)
# *   **Business Practices:**
#     *   Artisan co-operative ownership model.
#     *   Transparent pricing: Breakup of gold cost, making charge, artisan premium.
#     *   **Buy-Back & Recycle Program:** Encourages upgrading and ensures gold loop-back.
# *   **Customer Experience:**
#     *   In-store styling consultants and AR mirrors.
#     *   Subscription for occasion-based leasing.
#     *   Workshops on jewellery care and styling.
# *   **Marketing:**
#     *   #WearYourHeritage campaign featuring diverse models—from professionals to dancers.
#     *   Collaboration with South Indian cinema (**Kollywood, Tollywood**) for contemporary on-screen placement.
#
# ### **Conclusion**
#
# The future of South Indian jewellery lies not in diluting its essence, but in **innovating around it.** By focusing on **adaptability (modular/lightweight), authenticity (transparency/artisan support), and accessibility (price/style),** the industry can preserve its glorious heritage while becoming relevant for the next generation. The goal is to transform the narrative from "locked-away heirloom" to "living, worn, and celebrated heritage."
